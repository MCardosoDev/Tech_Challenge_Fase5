# %%
import pandas as pd

# %%
df_docentes = pd.read_csv('Data/docentes.csv', sep=';')
df_escolas = pd.read_csv('Data/escolas.csv', sep=';')
df_matriculas = pd.read_csv('Data/matriculas.csv', sep=';')

# %%
df_docentes.head()
# Out:
#   Medida  Etapa de Ensino   Ano  Docentes
# 0  Total  Educação Básica  2007       636
# 1  Total  Educação Básica  2008       646
# 2  Total  Educação Básica  2009       689
# 3  Total  Educação Básica  2010       746
# 4  Total  Educação Básica  2011       770

# %%
df_escolas.head()
# Out:
#    Escolas 'Localização'  Categoria 1 - Ordenação Etapa de Ensino - Superior  \
# 0       60        Urbana                        1            Educação Básica
# 1       54        Urbana                        1            Educação Básica
# 2       58        Urbana                        1            Educação Básica
# 3       60        Urbana                        1            Educação Básica
# 4       60        Urbana                        1            Educação Básica
#
#    Etapa de Ensino   Ano
# 0  Educação Básica  2007
# 1  Educação Básica  2008
# 2  Educação Básica  2009
# 3  Educação Básica  2010
# 4  Educação Básica  2011

# %%
df_matriculas.head()
# Out:
#    Matrículas 'Localização'  Categoria 1 - Ordenação  \
# 0       18824        Urbana                        1
# 1       18730        Urbana                        1
# 2       18503        Urbana                        1
# 3       18279        Urbana                        1
# 4       18582        Urbana                        1
#
#   Etapa de Ensino - Superior  Etapa de Ensino   Ano
# 0            Educação Básica  Educação Básica  2007
# 1            Educação Básica  Educação Básica  2008
# 2            Educação Básica  Educação Básica  2009
# 3            Educação Básica  Educação Básica  2010
# 4            Educação Básica  Educação Básica  2011
